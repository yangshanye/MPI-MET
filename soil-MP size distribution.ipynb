# %%
#Soil

# %%
Size =  [50, 100, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 4000, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000]
Altay=    [73.33333944, 36.66666972, 9.166667431, 3.666666972, None, 1.833333486, 0.916666743, 0.458333372, None, None, None, None, None, 1.000000083, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.550000046, None, None, None, None, None, None, None, None, None]
Singapore =    [87.5, None, None, None, 2, None, None, None, 3.75, None, None, None, None, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.25, None, None, None, None, None, None, None, None]
Todos =    [None, 56, 34, None, 4, None, None, 2, None, 1, None, None, 0.075, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.075, None, None, None, None, None, None, None, None]
Victoria=    [ None, None, None, None, None, 2, None, None, None, None, None, None, None, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.333333333, None, None, None, None, None, None, None, None]
Tibet =        [8.5, None, None, 1.5, None, None, None, 1, None, None, None, None, None, 0.06875, None, None, None, None, None, None, None, 0.06875, None, None, None, None, None, 0.06875, None, None, None, None, None, None, None, None, None, 0.06875]
Guanaba =     [None, None, None, None, None, 2.738788086, None, None, None, None, None, None, None, None, 1.027045532, None, None, None, None, 0.342348511, None, None, None, 0.136939404, None, None, None, None, None, None, None, None, None, None, 0.102704553, None, None, None]
Chile =   [None, None, None, None, 4, None, None, None, None, None, None, None, None, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
Swiss =   [30.0120048, 10.0040016, 2.00080032, None, 1.00040016, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
len(Swiss)
# Out:
# 38

# %%
# Ocean

# %%
Size=[500,333,100]
MP = [1,2.5,11.4]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

#plt.scatter(Size, Beijing, label=r'Beijing')
plt.scatter(Size, MP)

y = 9707.9 * np.power(Size, -1.455)

# Plot the function
plt.plot(Size, y, label=r'C$_{D}$/C$_{1000}$ = 9707.9 D$^{-1.455}$')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('D (μm)')
plt.ylabel(r'C$_{D}$/C$_{1000}$')

plt.xlim(50,1e3)


plt.gcf().set_dpi(300)

plt.legend(fontsize=8)
plt.show()

# %%
#sub plot

# %%
import string
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

fig = plt.figure(figsize=(10, 8))
# A
plt.subplot(2, 2,1)

Size = [5000, 4000, 3500, 3000, 2500, 2000, 1300, 1100, 1000, 700, 500, 300, 200, 100, 90, 80, 70, 60, 50, 45, 40, 35, 30, 25, 20, 15, 10, 5, 1]

Paris_indoor =         [None, None, None, None, None, 0.33333334, 0.33333334, 1, 1, 2.33333334, 4, 10, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
Paris_outdoor =     [None, None, None, None, None, 0.333364441, 0.666728895, 0.333364441, 1.000093337, 5.000466709, 3.333644477, 7.334017836, None, 12.667849, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
Paris_dep =       [None, None, None, None, None, 0.2, 0.62, 0.84, 1, 1.5, 3, 5.4, None, 6.4, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
Shanghai =       [0.142506001, None, None, None, None, 0.272727003, None, None, 0.999999006, None, 2.713756507, None, None, 5.713753519, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
Beijing =        [None, None, None, None, None, None, None, None, None, None, None, None, None, 1, 1, 1, 2, 2.5, 2, 2, 2, 2, 2.5, 3, 6.5, 7.5, 25, 45, None]
Dongguan =      [0.150000058, 0.1, 0.150000058, 0.250000058, 0.350000115, None, 0.85000023, None, 1.00000023, None, 1.500000403, None, None, 5.750001438, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
South_East =       [None, None, None, None, 1.00000025, None, None, None, None, None, None, None, 45.00001125, 75.00001875, None, None, None, None, None, None, None, 175.0000437, None, None, None, 325.0000812, None, None, None]
Pyrenees =         [None, None, None, None, None, None, None, None, None, None, None, None, 1.00000009, 3.0000003, None, 5.00000051, None, 9.0000009, None, None, None, None, 32.0000033, 53.0000054, None, None, None, None, None]
Iran =        [None, None, None, None, None, None, None, 1.000000225, None, 1.000000225, None, 2.000000525, None, 7.500001875, None, None, None, None, 38.5000096, None, None, None, None, None, None, None, None, None, None]
Wenzhou =       [None, None, None, None, 1, None, None, None, None, None, None, None, 8.375, 12.5, None, None, None, None, None, None, None, 31.25, None, None, None, 67.75, None, None, None]
#Dongguan_total =       [0.150011271, 0.100007476, 0.150011271, 0.250018746, 0.350026279, None, 0.850063772, None, 1.000074986, None, 1.500112536, None, None, 5.750431282, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None],
Arctic =        [None, None, None, None, None, None, None, None, None, None, None, None, None, 1, None, None, None, 1, None, None, None, 3, None, None, 13.5, 45, None, None, None]
Average =     [0.095486371, 0.129207281, 0.193810996, 0.323018276, 0.399465961, 0.226530697, 0.571849215, 0.506536581, 1.000544297, 1.306258305, 2.388061736, 4.066426519, 3.970612506, 7.429420505, 7.429420505, 9.905894019, 14.85884101, 16.09707776, 26.49826646, 14.85884101, 14.85884101, 18.26399207, 48.91035178, 76.77067868, 74.29420505, 115.6265478, 185.7355126, 334.3239227, None]

plt.scatter(Size, Paris_indoor, label=r'Paris_indoor')
plt.scatter(Size, Paris_outdoor, label=r'Paris_outdoor')
plt.scatter(Size, Paris_dep, label='Paris_dep')
plt.scatter(Size, Shanghai, label='Shanghai')
plt.scatter(Size, Dongguan, label='Dongguan')
plt.scatter(Size, Pyrenees, label='Pyrenees')
plt.scatter(Size, Iran, label='Iran')
plt.scatter(Size, Wenzhou, label='Wenzhou')
plt.scatter(Size, Average, label='Average',color='c')

y1 = 1786 * np.power(Size, -1.127)

# Plot the function
plt.plot(Size, y1, label=r'C$_{D}$/C$_{1000}$ = 1786 D$^{-1.127}$',color='green')
plt.text(-0.05, 1.02, string.ascii_lowercase[0], transform=plt.gca().transAxes, 
            size=20, weight='bold')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('D (μm)')
plt.ylabel(r'C$_{D}$/C$_{1000}$')
plt.xlim(1,1e4)
plt.legend(fontsize=7)

# B

plt.subplot(2, 2, 2)
Size =  [50, 100, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 4000, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000]
Altay=    [73.33333944, 36.66666972, 9.166667431, 3.666666972, None, 1.833333486, 0.916666743, 0.458333372, None, None, None, None, None, 1.000000083, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.550000046, None, None, None, None, None, None, None, None, None]
Singapore =    [87.5, None, None, None, 2, None, None, None, 3.75, None, None, None, None, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.25, None, None, None, None, None, None, None, None]
Todos =    [None, 56, 34, None, 4, None, None, 2, None, 1, None, None, 0.075, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.075, None, None, None, None, None, None, None, None]
Victoria=    [ None, None, None, None, None, 2, None, None, None, None, None, None, None, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 0.333333333, None, None, None, None, None, None, None, None]
Tibet =        [8.5, None, None, 1.5, None, None, None, 1, None, None, None, None, None, 0.06875, None, None, None, None, None, None, None, 0.06875, None, None, None, None, None, 0.06875, None, None, None, None, None, None, None, None, None, 0.06875]
Guanaba =     [None, None, None, None, None, 2.738788086, None, None, None, None, None, None, None, None, 1.027045532, None, None, None, None, 0.342348511, None, None, None, 0.136939404, None, None, None, None, None, None, None, None, None, None, 0.102704553, None, None, None]
Chile =   [None, None, None, None, 4, None, None, None, None, None, None, None, None, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
Swiss =   [30.0120048, 10.0040016, 2.00080032, None, 1.00040016, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
plt.scatter(Size, Altay, label=r'Altay')
plt.scatter(Size, Singapore, label=r'Singapore')
plt.scatter(Size, Todos, label='Todos os Santos Bay')
plt.scatter(Size, Victoria, label='Victoria')
plt.scatter(Size, Tibet, label='Tibet')
plt.scatter(Size, Guanaba, label='Guanaba')
plt.scatter(Size, Chile, label='Chile')
plt.scatter(Size, Swiss, label='Swiss')

y2 = 16571 * np.power(Size, -1.395)

# Plot the function
plt.plot(Size, y2, label=r'C$_{D}$/C$_{1000}$ = 16571 D$^{-1.395}$',color='orange')
plt.text(-0.05, 1.02, string.ascii_lowercase[1], transform=plt.gca().transAxes, 
            size=20, weight='bold')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('D (μm)')
plt.ylabel(r'C$_{D}$/C$_{1000}$')
plt.xlim(1,1e4)
plt.legend(fontsize=8)


# C

plt.subplot(2, 2, 3)
Size=[500,333,100]
MP = [1,2.5,11.4]
plt.scatter(Size, MP)
y3 = 9707.9 * np.power(Size, -1.455)

# Plot the function
plt.plot(Size, y3, label=r'C$_{D}$/C$_{1000}$ = 9707.9 D$^{-1.455}$',color='blue')
plt.text(-0.05, 1.02, string.ascii_lowercase[2], transform=plt.gca().transAxes, 
            size=20, weight='bold')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('D (μm)')
plt.ylabel(r'C$_{D}$/C$_{1000}$')
plt.xlim(50,1e3)
plt.legend(fontsize=8)

# D

plt.subplot(2, 2, 4)
Size1 = [5000, 4000, 3500, 3000, 2500, 2000, 1300, 1100, 1000, 700, 500, 300, 200, 100, 90, 80, 70, 60, 50, 45, 40, 35, 30, 25, 20, 15, 10, 5, 1]
Size2 =  [1,50, 100, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 4000, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000]
Size3 =[5000,500,333,100,1]
y1 = 1786 * np.power(Size1, -1.127)
y2 = 16571 * np.power(Size2, -1.395)
y3 = 9707.9 * np.power(Size3, -1.455)
y4= 1786* np.power(Size3, -1.256)
y5= 16571* np.power(Size3, -1.389)
y6=  9178.5* np.power(Size3, -1.367)
plt.text(-0.05, 1.02, string.ascii_lowercase[3], transform=plt.gca().transAxes, 
            size=20, weight='bold')
plt.plot(Size1, y1, label=r'Air',color='green')
plt.plot(Size2, y2, label=r'Soil',color='orange')
plt.plot(Size3, y3, label=r'Ocean',color='blue')
plt.plot(Size3, y4, linestyle='--',color="gray",label=r'Error limitation')
plt.plot(Size3, y5, linestyle='--',color="gray")
plt.plot(Size3, y6, color="red",label=r'Environmental average size distribution')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('D (μm)')
plt.ylabel(r'C$_{D}$/C$_{1000}$')
plt.legend(fontsize=8)



# Adjust the layout
plt.tight_layout()

plt.gcf().set_dpi(300)

# Display the subplots
plt.show()

# %%
Size2 =  [1,10,50, 100, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 4000, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000]

y6=  9178.5* np.power(Size2, -1.367)

display(list(y6))
# Out:
# [9178.5,
#  394.25000930615175,
#  43.67970698304072,
#  16.934474024938797,
#  3.771785243312287,
#  2.545398032656732,
#  1.8762025259632604,
#  1.462308326732116,
#  1.1844662528316299,
#  0.9868421709855308,
#  0.8400830105923376,
#  0.727397346181501,
#  0.6385397114137518,
#  0.5669319710663695,
#  0.508172488713177,
#  0.45921354279646975,
#  0.4178832475382441,
#  0.38259535755945495,
#  0.35216649642732395,
#  0.3256973295904188,
#  0.30249314673313255,
#  0.16201191559368908,
#  0.15491029350169533,
#  0.14833092051575225,
#  0.1422208128361388,
#  0.13653375441638688,
#  0.13122926476536806,
#  0.126271748344886,
#  0.12162978959148671,
#  0.11727556547169932,
#  0.10933411756417466,
#  0.10227981463718,
#  0.09904221250083718,
#  0.09597804589691915,
#  0.09307439157372122,
#  0.09031954817217992,
#  0.08770289725167561,
#  0.08521478267806758,
#  0.0828464056238719,
#  0.08058973288895145]

# %%
data = [
    (798.5377742, 0.03133029),
    (2884.615385, 0.00739743),
    (2746.74968, 0.001952921),
    (2746.74968, 0.001469913),
    (2746.74968, 0.002939826),
    (493.7617555, 0.26477231),
    (1098.669619, 0.001308353)
]

# Extract the data into separate lists
urban_density = [item[0] for item in data]
urban_concentration = [item[1] for item in data]

# %%
road_density=[16.2,423,29]
road_concentration=[0.26,0.0072,0.0006]

# %%
sand_density=[0.00204,0]
sand_concentration=[0.00022,0.0226]

# %%
data = [
    (6.138613861, 0.134167179),
    (1.2, 0.000180329),
    (9.508716323, 0.000180329),
    (1.423220974, 0.000180329),
    (1112.811239, 0.000180329),
    (25.12908414, 0.012880626),
    (244.9860613, 1.0249E-05),
    (1295.031787, 0.095731442),
    (3785.488959, 0.000813888),
    (602.5548325, 0.001295791),
    (399.573788, 0.010304501),
    (144.076841, 0.013368277),
    (636.5372374, 0.008997878),
    (317.3749328, 0.011054536),
    (184.8249027, 0.011568701),
    (72.12273088, 0.001028329),
    (232.6621924, 0.000105858),
    (1135.605007, 0.025761252),
    (708.2630691, 0.009866866),
    (2470, 0.05841364),
    (637.3900293, 0.002576125),
    (57.30659026, 0.0268094),
    (1391.304348, 0.001495499)
]

agr_density = [item[0] for item in data]
agr_concentration = [item[1] for item in data]

# %%
import matplotlib.pyplot as plt
import string
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick
plt.figure(figsize=(11, 8))
plt.subplot(2, 2, 1)
plt.scatter(urban_density, urban_concentration,label='Urban',marker ="^")
plt.scatter(road_density, road_concentration,label='Road',marker ="v")
plt.scatter(sand_density, sand_concentration,label='Sand',marker ="o")
plt.scatter(agr_density, agr_concentration,label='Agriculture',marker ="s")
plt.yscale('log')
plt.xlabel('Population density (people/km$^{2}$)')
plt.ylabel('10 μm Microplastic soil concentration (mg/kg)')
plt.legend()
plt.text(-0.1, 1.07, string.ascii_lowercase[0], transform=plt.gca().transAxes, 
            size=20, weight='bold')
plt.title('Microplastic soil concentration vs Population density')


from statistics import mean
import numpy as np
import statistics
plt.subplot(2, 2, 2)
Soils= ['Urban','Road', 'Desert', 'Agriculture']
positions = range(len(Soils))
plt.xticks(positions,fontsize=11)
plt.ylabel(r'Concentration(mg/kg)',fontsize=12)
# 计算所需值
urban_mean = (max(urban_concentration) + min(urban_concentration)) / 2
urban_err = (max(urban_concentration) - min(urban_concentration)) / 2

road_max = max(road_concentration)
road_min = min(road_concentration)
road_mean = (road_max + road_min) / 2
road_err = (road_max - road_min) / 2

sand_median = statistics.median(sand_concentration)
sand_err = (max(sand_concentration) - min(sand_concentration)) / 2

agr_max = max(agr_concentration)
agr_min = min(agr_concentration)
agr_mean = (agr_max + agr_min) / 2
agr_err = (agr_max - agr_min) / 2


# 绘制误差棒图
plt.errorbar(
    Soils,
    [urban_mean, road_mean, sand_median, agr_mean],
    yerr=[urban_err, road_err, sand_err, agr_err],
    fmt='o',
    markersize=9,
    color='black',
    ecolor='c',
    linewidth=20,
    capsize=12
)
plt.text(-0.1, 1.07, string.ascii_lowercase[1], transform=plt.gca().transAxes, 
            size=20, weight='bold')
for i, soil in enumerate(Soils):
    plt.text(i, [urban_mean, road_mean, sand_median, agr_mean][i] + 0.3, ['N=7',' N=3',' N=2', 'N=23'][i], ha='center')

plt.yscale('log')
plt.ylim(1e-6,1e0)
plt.title("10 Microplastic concentration range in Soils")


import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import string


# Example data
data10 = [
    0.03133029, 0.00739743, 0.001952921, 0.001469913, 0.002939826, 0.26477231, 0.001308353,
    0.26, 0.0072, 0.0006,
    0.00022, 0.0226,
    0.134167179, 0.000180329, 0.000180329, 0.000180329, 0.000180329, 0.012880626,
    1.0249e-05, 0.095731442, 0.000813888, 0.001295791, 0.010304501, 0.013368277,
    0.008997878, 0.011054536, 0.011568701, 0.001028329, 0.000105858, 0.025761252,
    0.009866866, 0.05841364, 0.002576125, 0.0268094, 0.001495499
]

# Calculate mean and standard deviation
mean = np.mean(data10)
std_dev = np.std(data10, ddof=1)  # Using Bessel's correction

# Calculate confidence interval bounds (95% confidence interval)
z_critical = norm.ppf(0.995)  # Z-score for 95% confidence interval
margin_of_error = z_critical * (std_dev / np.sqrt(len(data10)))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

# Create a range of x values
x = np.linspace(mean - 3 * std_dev, mean + 3 * std_dev, 1000)

# Calculate the probability density function of the normal distribution
y = norm.pdf(x, mean, std_dev)


plt.subplot(2, 2, 3)
# Plot the normal distribution curve
plt.plot(x, y, color='blue', label='Normal Distribution')

# Shade the area within the confidence interval
plt.fill_between(x, y, where=(x >= lower_bound) & (x <= upper_bound), color='green', alpha=0.5, label='99% Confidence Interval')

# Plot data points as scatter plot
plt.scatter(data10, np.zeros_like(data10), color='red', marker='o', label='Data Points')
peak_x = x[np.argmax(y)]
plt.axvline(x=peak_x, color='purple', linestyle='--', label=f'Peak at {peak_x:.4f}')

plt.xlabel('10 μm Microplastic Concentration (mg/Kg)')
plt.ylabel('Probability Density')
plt.title(' 99% Confidence Interval of 10 μm Microplastic Concentration')

# Add vertical lines for the confidence interval bounds

plt.axvline(x=lower_bound, color='red', linestyle='--', label=f'Lower Bound {lower_bound:.4f}')
plt.axvline(x=upper_bound, color='red', linestyle='--', label=f'Upper Bound {upper_bound:.4f}')
plt.text(-0.05, 1.02, string.ascii_lowercase[2], transform=plt.gca().transAxes, 
            size=20, weight='bold')

# Add legend to the plot
plt.legend()

plt.grid(True)


# Example data
data1 = [
   2.46447E-06, 0.000599745, 0.000729398, 0.000172219, 0.00022971, 0.001359923,
    4.54658E-05, 3.42209E-05, 6.84418E-05,
    0.006164141, 0.000169417, 5.99745E-05,
    3.04596E-05, 0.006091945, 0.000624147, 3.48166E-05, 1.49936E-05, 5.99745E-06,
    0.003123534, 4.19822E-06, 4.19822E-06, 4.19822E-06, 4.19822E-06, 0.000299873,
    2.38605E-07, 0.002228715, 1.89481E-05, 3.01672E-05, 0.000239898, 0.000324473,
    0.000218395, 0.000268314, 0.000280794, 2.49594E-05, 0.000527384
]

# Calculate mean and standard deviation
mean = np.mean(data1)
std_dev = np.std(data1, ddof=1)  # Using Bessel's correction

# Calculate confidence interval bounds (95% confidence interval)
z_critical = norm.ppf(0.995)  # Z-score for 95% confidence interval
margin_of_error = z_critical * (std_dev / np.sqrt(len(data1)))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

# Create a range of x values
x = np.linspace(mean - 3 * std_dev, mean + 3 * std_dev, 1000)

# Calculate the probability density function of the normal distribution
y = norm.pdf(x, mean, std_dev)

plt.subplot(2, 2, 4)
# Plot the normal distribution curve
plt.plot(x, y, color='blue', label='Normal Distribution')

# Shade the area within the confidence interval
plt.fill_between(x, y, where=(x >= lower_bound) & (x <= upper_bound), color='green', alpha=0.5, label='99% Confidence Interval')

# Plot data points as scatter plot
plt.scatter(data1, np.zeros_like(data1), color='red', marker='o', label='Data Points')
peak_x = x[np.argmax(y)]
plt.axvline(x=peak_x, color='purple', linestyle='--', label=f'Peak at {peak_x:.4f}')
plt.xlabel('1 μm Microplastic Concentration (mg/Kg)')
plt.ylabel('Probability Density')
plt.title(' 99% Confidence Interval of 1 μm Microplastic Concentration')

# Add vertical lines for the confidence interval bounds
plt.axvline(x=lower_bound, color='red', linestyle='--', label=f'Lower Bound {lower_bound:.4f}')
plt.axvline(x=upper_bound, color='red', linestyle='--', label=f'Upper Bound {upper_bound:.4f}')

plt.text(-0.1, 1.07, string.ascii_lowercase[3], transform=plt.gca().transAxes, 
            size=20, weight='bold')
# Add legend to the plot
plt.legend()
plt.gcf().set_dpi(200)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#计算置信区间数值

import numpy as np
from scipy import stats

# 生成样本数据
data= [
   2.46447E-06, 0.000599745, 0.000729398, 0.000172219, 0.00022971, 0.001359923,
    4.54658E-05, 3.42209E-05, 6.84418E-05,
    0.006164141, 0.000169417, 5.99745E-05,
    3.04596E-05, 0.006091945, 0.000624147, 3.48166E-05, 1.49936E-05, 5.99745E-06,
    0.003123534, 4.19822E-06, 4.19822E-06, 4.19822E-06, 4.19822E-06, 0.000299873,
    2.38605E-07, 0.002228715, 1.89481E-05, 3.01672E-05, 0.000239898, 0.000324473,
    0.000218395, 0.000268314, 0.000280794, 2.49594E-05, 0.000527384
]

# 计算样本均值和标准差
sample_mean = np.mean(data)
sample_std = np.std(data)

# 设置置信水平
confidence_level = 0.99

# 计算Z值
z_value = stats.norm.ppf((1 + confidence_level) / 2)

# 计算置信区间
lower_bound = sample_mean - z_value * (sample_std / np.sqrt(len(data)))
upper_bound = sample_mean + z_value * (sample_std / np.sqrt(len(data)))

# 打印结果
print("置信区间为: [{}, {}]".format(lower_bound, upper_bound))
# Out:
# 置信区间为: [3.977474818954072e-05, 0.0013339375892390307]

# %%
# Example data
data10 = [
    0.03133029, 0.00739743, 0.001952921, 0.001469913, 0.002939826, 0.26477231, 0.001308353,
    0.26, 0.0072, 0.0006,
    0.00022, 0.0226,
    0.134167179, 0.000180329, 0.000180329, 0.000180329, 0.000180329, 0.012880626,
    1.0249e-05, 0.095731442, 0.000813888, 0.001295791, 0.010304501, 0.013368277,
    0.008997878, 0.011054536, 0.011568701, 0.001028329, 0.000105858, 0.025761252,
    0.009866866, 0.05841364, 0.002576125, 0.0268094, 0.001495499
]
plt.figure(figsize=(15, 8))

# Calculate mean and standard deviation
mean = np.mean(data10)
std_dev = np.std(data10, ddof=1)  # Using Bessel's correction

# Calculate confidence interval bounds (95% confidence interval)
z_critical = norm.ppf(0.995)  # Z-score for 95% confidence interval
margin_of_error = z_critical * (std_dev / np.sqrt(len(data10)))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

# Create a range of x values
x = np.linspace(mean - 3 * std_dev, mean + 3 * std_dev, 1000)

# Calculate the probability density function of the normal distribution
y = norm.pdf(x, mean, std_dev)


plt.subplot(2, 2, 3)
# Plot the normal distribution curve
plt.plot(x, y, color='blue', label='Normal Distribution')

# Shade the area within the confidence interval
plt.fill_between(x, y, where=(x >= lower_bound) & (x <= upper_bound), color='green', alpha=0.5, label='99% Confidence Interval')

# Plot data points as scatter plot
plt.scatter(data10, np.zeros_like(data10), color='red', marker='o', label='Data Points')
peak_x = x[np.argmax(y)]
plt.axvline(x=peak_x, color='purple', linestyle='--', label=f'Peak at {peak_x:.4f}')

plt.xlabel('10 μm Microplastic Concentration (mg/Kg)')
plt.ylabel('Probability Density')
plt.title(' 99% Confidence Interval of 10 μm Microplastic Concentration')

# Add vertical lines for the confidence interval bounds

plt.axvline(x=lower_bound, color='red', linestyle='--', label=f'Lower Bound {lower_bound:.4f}')
plt.axvline(x=upper_bound, color='red', linestyle='--', label=f'Upper Bound {upper_bound:.4f}')
plt.gcf().set_dpi(200)

# Add legend to the plot
plt.legend()

plt.grid(True)

# %%
import matplotlib.pyplot as plt
import string
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick
plt.figure(figsize=(11, 8))
plt.subplot(2, 2, 2)
plt.scatter(urban_density, urban_concentration,label='Urban',marker ="^")
plt.scatter(road_density, road_concentration,label='Road',marker ="v")
plt.scatter(sand_density, sand_concentration,label='Desert',marker ="o")
plt.scatter(agr_density, agr_concentration,label='Agriculture',marker ="s")
plt.yscale('log')
plt.xlabel('Population density (people/km$^{2}$)')
plt.ylabel('Concentration (mg/kg)')
plt.legend()
plt.text(-0.1, 1.07, string.ascii_lowercase[1], transform=plt.gca().transAxes, 
            size=20, weight='bold')
plt.title('10 μm Microplastic concentration vs Population density')


from statistics import mean
import numpy as np
import statistics
plt.subplot(2, 2, 3)
Soils= ['Urban','Road', 'Desert', 'Agriculture']
positions = range(len(Soils))
plt.xticks(positions)
plt.ylabel(r'Concentration(mg/kg)')
# 计算所需值
urban_mean = (max(urban_concentration) + min(urban_concentration)) / 2
urban_err = (max(urban_concentration) - min(urban_concentration)) / 2

road_max = max(road_concentration)
road_min = min(road_concentration)
road_mean = (road_max + road_min) / 2
road_err = (road_max - road_min) / 2

sand_median = statistics.median(sand_concentration)
sand_err = (max(sand_concentration) - min(sand_concentration)) / 2

agr_max = max(agr_concentration)
agr_min = min(agr_concentration)
agr_mean = (agr_max + agr_min) / 2
agr_err = (agr_max - agr_min) / 2


# 绘制误差棒图
plt.errorbar(
    Soils,
    [urban_mean, road_mean, sand_median, agr_mean],
    yerr=[urban_err, road_err, sand_err, agr_err],
    fmt='o',
    markersize=9,
    color='black',
    ecolor='c',
    linewidth=20,
    capsize=12
)
plt.text(-0.1, 1.07, string.ascii_lowercase[2], transform=plt.gca().transAxes, 
            size=20, weight='bold')
for i, soil in enumerate(Soils):
    plt.text(i, [urban_mean, road_mean, sand_median, agr_mean][i] + 0.3, ['N=7',' N=3',' N=2', 'N=23'][i], ha='center')

plt.yscale('log')
plt.ylim(1e-6,1e0)
plt.title("10 μm Microplastic concentration range vs Soil type")


import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import string


# Example data
data10 = [
    0.03133029, 0.00739743, 0.001952921, 0.001469913, 0.002939826, 0.26477231, 0.001308353,
    0.26, 0.0072, 0.0006,
    0.00022, 0.0226,
    0.134167179, 0.000180329, 0.000180329, 0.000180329, 0.000180329, 0.012880626,
    1.0249e-05, 0.095731442, 0.000813888, 0.001295791, 0.010304501, 0.013368277,
    0.008997878, 0.011054536, 0.011568701, 0.001028329, 0.000105858, 0.025761252,
    0.009866866, 0.05841364, 0.002576125, 0.0268094, 0.001495499
]

# Calculate mean and standard deviation
mean = np.mean(data10)
std_dev = np.std(data10, ddof=1)  # Using Bessel's correction

# Calculate confidence interval bounds (95% confidence interval)
z_critical = norm.ppf(0.995)  # Z-score for 95% confidence interval
margin_of_error = z_critical * (std_dev / np.sqrt(len(data10)))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

# Create a range of x values
x = np.linspace(mean - 3 * std_dev, mean + 3 * std_dev, 1000)

# Calculate the probability density function of the normal distribution
y = norm.pdf(x, mean, std_dev)

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick
plt.subplot(2, 2, 1)
#plt.scatter(Size, Beijing, label=r'Beijing')
plt.scatter(x1, f1, label=r'Altay')
plt.scatter(x2, f2, label=r'Singapore')
plt.scatter(x3, f3, label='Todos os Santos Bay')
plt.scatter(x4, f4, label='Victoria')
plt.scatter(x5, f5, label='Victoria')
plt.scatter(x6, f6, label='Guanabara Bay')
plt.scatter(x7, f7, label='Chile')
plt.scatter(x8, f8, label='Swiss')


y = 7e-10*np.power([1,4000], 1.5874)

# Plot the function


plt.plot([1,4000], y, label=r'MSDSM fuction: $y = 7\times10^{-10} \times D^{1.5874}$' + f'\n$R^2$ = {0.8632}', color='blue')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Diameter (D,μm)')
plt.ylabel(r'dP/dD (μm$^{-1}$)')
plt.title('Mass-based size distribution of soil microplastics (MSDSM)')
plt.legend(fontsize=7)
plt.xlim(1,1e5)
plt.text(-0.1, 1.07, string.ascii_lowercase[0], transform=plt.gca().transAxes, 
            size=20, weight='bold')

import numpy as np
plt.subplot(2, 2, 4)
# 准备数据
size_bins = ["0-2.5", "2.5-10", "10-50", "50-100", "100-200"]  # 尺寸区间


soil_con_min = [0.000139094435701090, 0.00488525433140102, 0.318267509626405, 1.61973936041761, 9.73486978381569]
soil_con_mean = [0.00312427501728602, 0.109730328059161, 7.14877790853157, 36.3818379416879, 218.660152067245]
soil_con_max = [0.00615225388677898, 0.216078556965814, 14.0772167719372, 71.6423178646252, 430.580778899540]

# 计算误差条的长度
error = [np.subtract(soil_con_mean, soil_con_min), np.subtract(soil_con_max, soil_con_mean)]

plt.bar(size_bins, soil_con_mean, color='skyblue', edgecolor='gray', yerr=error)
plt.xlabel('Size Bin (μm)')
plt.ylabel('Concentration (mg/Kg)')
plt.title('Microplastic concentration vs Size bin')
plt.yscale('log')  # 由于数据范围很大，使用对数刻度
plt.grid(True, which="both", linestyle='--', linewidth=0.5)

# # 添加上边框和右边框
# ax = plt.gca()  # 获取当前的axes
# ax.spines['top'].set_visible(True)   # 显示上边框
# ax.spines['right'].set_visible(True) # 显示右边框
# ax.text(-0.1, 1.02, 'd', transform=ax.transAxes, size=20, weight='bold')
plt.tight_layout()
# plt.gcf().set_dpi(200)

# 显示图形


plt.gcf().set_dpi(300)

plt.show()

# %%
# ？-？μm微塑料在土壤中的质量

# %%
from sympy import symbols, integrate

Soil_con_10um=[0.0013,0.0292,0.0575] #mg/kg 10μm MP在土壤中的浓度[vim, mean, vmax]

d = symbols('d')
p = 7*1e-10*d**1.5874
def P(d):
    Probability = 7*1e-10*d**1.5874 
    return Probability
# 计算在 Δd μm 范围内的积分
result = integrate(p, (d,0,2.5))

#Δd μm 范围内concentration
soil_con = [x / P(10) * result for x in Soil_con_10um] #mg/Kg
soil_con

# %%
f1
# Out:
# array([1.06838231e-06, 2.57228473e-06, 5.41118509e-06, 1.00957068e-04,
#        3.97208138e-04])

# %%
import math
import numpy as np
x1=[110,350,750,2000,4000]
y1=[0.388,0.029,0.0062,0.0061,0.003]
r1=[180,300,500,2000,2000]
t1=sum([(y*r* math.pi / 6 * x ** 3/1e6)for y,r,x in zip(y1,r1,x1)])
f1 = np.array([(y * math.pi / 6 * x ** 3/1e6) for x, y in zip(x1, y1)])/t1

x2=[10,30,50,70,90,350,750,1500,3500]
y2=[1.85,1,0.4,0.1,0.1,0.0185,0.028,0.004,0.001]
r2=[20,20,20,20,20,400,500,1000,3000]
t2=sum([(y*r* math.pi / 6 * x ** 3/1e6)for y,r,x in zip(y2,r2,x2)])
f2 = np.array([(y * math.pi / 6 * x ** 3/1e6) for x, y in zip(x2, y2)])/t2

x3=[100,300,500,700,900,3000]
y3=[0.28, 0.175, 0.025, 0.01, 0.005, 0.000375]
r3=[200,200,200,200,200,4000]
t3=sum([(y*r* math.pi / 6 * x ** 3/1e6)for y,r,x in zip(y3,r3,x3)])
f3 = np.array([(y * math.pi / 6 * x ** 3/1e6) for x, y in zip(x3, y3)])/t3

x4=[500,1500,2500,3500,4500]
y4=[0.038265306, 0.035, 0.02, 0.005, 0.01]
r4=[800,1000,1000,1000,1000]
t4=sum([(y*r* math.pi / 6 * x ** 3/1e6)for y,r,x in zip(y4,r4,x4)])
f4 = np.array([(y * math.pi / 6 * x ** 3/1e6) for x, y in zip(x4, y4)])/t4

x5=[25,75,300,750,3000]
y5=[0.32, 0.36, 0.08, 0.046, 0.00275]
r5=[50,50,400,500,4000]
t5=sum([(y*r* math.pi / 6 * x ** 3/1e6)for y,r,x in zip(y5,r5,x5)])
f5 = np.array([(y * math.pi / 6 * x ** 3/1e6) for x, y in zip(x5, y5)])/t5

x6=[500,1500,2500,3500,4500]
y6=[0.059405941, 0.021782178, 0.00990099, 0.004950495, 0.003960396]
r6=[1000,1000,1000,1000,1000]
t6=sum([(y*r* math.pi / 6 * x ** 3/1e6)for y,r,x in zip(y6,r6,x6)])
f6 = np.array([(y * math.pi / 6 * x ** 3/1e6) for x, y in zip(x6, y6)])/t6

x7=[250, 750, 1250, 1750, 2250, 2750, 3250, 3750, 4250, 4750]
y7=[0.084, 0.16, 0.1, 0.04, 0.034, 0.02, 0.036, 0.014, 0.016, 0.004]
r7=[500,500,500,500,500,500,500,500,500,500]

def calculate_t_and_f(x, y, r):
    t = sum([(y_i * r_i * math.pi / 6 * x_i ** 3 / 1e6) for y_i, r_i, x_i in zip(y, r, x)])
    f = np.array([(y_i * math.pi / 6 * x_i ** 3 / 1e6) for x_i, y_i in zip(x, y)]) / t
    return t, f

t7, f7 = calculate_t_and_f(x7, y7, r7)

x8=[125, 175, 225, 275, 325, 375, 425, 475, 525, 575, 625, 675, 725, 775, 825, 875, 925, 975, 3000]
y8=[0.720379147, 0.473933649, 0.341232227, 0.132701422, 0.113744076, 0.037914692, 0.037914692, 0.018957346, 0.028436019, 0.037914692, 0.009478673, 0, 0, 0.018957346, 0, 0.009478673, 0, 0, 0.000236967]
r8=[50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,50,40000]
t8, f8 = calculate_t_and_f(x8, y8, r8)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

#plt.scatter(Size, Beijing, label=r'Beijing')
plt.scatter(x1, f1, label=r'Altay')
plt.scatter(x2, f2, label=r'Singapore')
plt.scatter(x3, f3, label='Todos os Santos Bay')
plt.scatter(x4, f4, label='Victoria')
plt.scatter(x5, f5, label='Victoria')
plt.scatter(x6, f6, label='Guanabara Bay')
plt.scatter(x7, f7, label='Chile')
plt.scatter(x8, f8, label='Swiss')


y = 7e-10*np.power([1,4000], 1.5874)

# Plot the function


plt.plot([1,4000], y, label=r'MSDSM fuction: $y = 7\times10^{-10} \times D^{1.5874}$' + f'\n$R^2$ = {0.8632}', color='blue')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Diameter interval mid-points (μm)')
plt.ylabel(f'Mass-based Size Distribution of Soil Microplastics (MSDSM)\nProbability Density')

plt.xlim(1,1e4)



plt.gcf().set_dpi(300)

plt.legend(fontsize=7)
plt.show()

# %%
all_x = x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8

# %%
all_f = np.concatenate((f1, f2, f3, f4, f5, f6, f7,f8))

# %%
f1
# Out:
# array([1.06838231e-06, 2.57228473e-06, 5.41118509e-06, 1.00957068e-04,
#        3.97208138e-04])

# %%
f2
# Out:
# array([1.24703201e-08, 1.81999267e-07, 3.37035679e-07, 2.31206476e-07,
#        4.91398020e-07, 5.34664976e-06, 7.96246792e-05, 9.09996334e-05,
#        2.89008095e-04])

# %%
all_x
# Out:
# [110,
#  350,
#  750,
#  2000,
#  4000,
#  10,
#  30,
#  50,
#  70,
#  90,
#  350,
#  750,
#  1500,
#  3500,
#  100,
#  300,
#  500,
#  700,
#  900,
#  3000,
#  500,
#  1500,
#  2500,
#  3500,
#  4500,
#  25,
#  75,
#  300,
#  750,
#  3000,
#  500,
#  1500,
#  2500,
#  3500,
#  4500,
#  250,
#  750,
#  1250,
#  1750,
#  2250,
#  2750,
#  3250,
#  3750,
#  4250,
#  4750,
#  125,
#  175,
#  225,
#  275,
#  325,
#  375,
#  425,
#  475,
#  525,
#  575,
#  625,
#  675,
#  725,
#  775,
#  825,
#  875,
#  925,
#  975,
#  3000]

# %%
# 荧光塑料size distribution

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import string

# Example data
data10 = [
    2,2,3,5,4,2,5,2,3,4,3,4,4,4.5,2,3,3,1,2,3,3,3,4.5,6,3,4,5.5,10,4,4,7,4,2,3.5,2.5,2.5,5,10,7,8,7,5,5,5,7,3,2,4.5,5.5,4,4.5,4,4,2.5,
    5.5,3,8,4,2,3,4,6,4,5,4,3,2,3,5,4,2,4,6,4,3,5,3,4,2,4,6,4,3,5,3,4,2,4,8,3,6,1,3,4,8,6,6,4,6,5,6,4,3,6,4
]

# Calculate mean and standard deviation
mean = np.mean(data10)
std_dev = np.std(data10, ddof=1)  # Using Bessel's correction

# Calculate confidence interval bounds (95% confidence interval)
z_critical = norm.ppf(0.995)  # Z-score for 95% confidence interval
margin_of_error = z_critical * (std_dev / np.sqrt(len(data10)))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

# Create a range of x values
x = np.linspace(mean - 3 * std_dev, mean + 3 * std_dev, 1000)

# Calculate the probability density function of the normal distribution
y = norm.pdf(x, mean, std_dev)


# Plot the normal distribution curve
plt.plot(x, y, color='c', label='Normal Distribution')

# Shade the area within the confidence interval
plt.fill_between(x, y, where=(x >= lower_bound) & (x <= upper_bound), color='yellow', alpha=0.5, label='99% Confidence Interval')

# Plot data points as scatter plot
plt.scatter(data10, np.zeros_like(data10), color='red', marker='o', label='Data Points')
peak_x = x[np.argmax(y)]
plt.axvline(x=peak_x, color='red', linestyle='--', label=f'Peak at {peak_x:.4f}')

plt.xlabel('Microplastic size distribution (μm)')
plt.ylabel('Probability Density')
plt.title(' 99% Confidence Interval of Microplastic size distribution')

# Add vertical lines for the confidence interval bounds

plt.axvline(x=lower_bound, color='blue', linestyle='--', label=f'Lower Bound {lower_bound:.4f}')
plt.axvline(x=upper_bound, color='blue', linestyle='--', label=f'Upper Bound {upper_bound:.4f}')


# Add legend to the plot
plt.legend()

plt.grid(True)

# %%
len(y7)
# Out:
# 13
