# %%
len(Dongguan)
# Out:
# 31

# %%
import matplotlib.pyplot as plt
import numpy as np

Size = [5000, 4000, 3500, 3000, 2500, 2000, 1300, 1100, 1000, 700, 500, 300, 200, 100, 90, 80, 70, 60, 50, 45, 40, 35, 30, 25, 20, 15, 10, 5, 1, 0.1]
Paris_ndoor = [0, None,None, None, None, 0.016666667, 0.016666667, 0.05, 0.05, 0.116666667, 0.2, 0.5, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None,None, None]
Paris_outdoor = [0, None, None, None, None, None, 0.026315789, 0.052631579, 0.026315789, 0.078947368, 0.394736842, 0.263157895, 0.578947368, None, None, None, None, None, None, None, None, None, None,None, None, None, None, None, None, None]

# Add the provided data
Paris_dep = [0, None, None, None,None, 0.03125, 0.096875, 0.13125, 0.15625, 0.234375, 0.46875, 0.84375, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None,None]
Shanghai = [0.024940873,  None, None,None, None, 0.047731671, 0, 0, 0.175016126, 0, 0.474951623, None, None, 1, None, None, None, None, None, None, None, None, None, None, None, None, None, None,None, None]
Beijing = [None,  None, None, None, None, None, None, None, None, None, None, None, None, 1, 1, 1, 2, 2.5, 2, 2, 2, 2, 2.5, 3, 6.5, 7.5, 25, 45, None,None,]
Dongguan = [0.02608696, 0.0173913, 0.02608696, 0.04347826, 0.06086957, None, 0.14782609, None, 0.17391304, None, 0.26086957, None, None, 1, None, None, None, None, None, None, None, None, None, None,None, None, None,  None, None, None]
South_East = [None, None, None, None, None, 0.013333333, None, None, None, None, None, None, None, None, 0.6, 1, None, None, None, None, 2.333333333, None, None, None, 4.333333333, None, None, None,None, None]
Pyrenees = [None, None, None, None, None, None, None, None, None, None, None, None, None, 0.33333333, 1, None, None, None, None, None, 1.66666667, None, None, None, 10.6666667, 17.6666667, None, None,None, None]
Iran = [None, None, None, None, None, None, 0.13333333, None, 0.13333333, None, 0.26666667, None, None, 1, None, None, None, None, None, None, None, 5.13333333, None, None, None, None, None, None,None, None]
Wenzhou = [None, None, None, 0.08, None, None, None, None, None, None, None, None, None, 0.67, 1, None, None, None, None, None, None, 2.5, None, None, None, 5.42, None, None,None, None]
Gdynia = [None, None,  None, None, None, None, None, None, None, None, None, None, None, None, None, 0.011764706, 0.152941177, None, 1, None, None, None, None, None, None, None, None, None,None, None]
Arctic = [None,   None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 1, None, None, None, None, None, 3, None, None, 13.5, 45, None,None]

plt.scatter(Size, Beijing, label=r'Beijing')
plt.scatter(Size, Paris_ndoor, label=r'Paris_ndoor')
plt.scatter(Size, Paris_outdoor, label=r'Paris_outdoor')
plt.scatter(Size, Paris_dep, label='Paris_dep')
plt.scatter(Size, Shanghai, label='Shanghai')

plt.scatter(Size, Dongguan, label='Dongguan')
plt.scatter(Size, South_East, label='South_East')
plt.scatter(Size, Pyrenees, label='Pyrenees')
plt.scatter(Size, Iran, label='Iran')
plt.scatter(Size, Wenzhou, label='Wenzhou')
plt.scatter(Size, Arctic, label='Arctic',color='black')

y = 240.21 * np.power(Size, -1.1289)

# Plot the function
plt.plot(Size, y, label=r'C$_{D}$/C$_{100}$ = 240.4D$^{-1.1289}$')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('D (μm)')
plt.ylabel(r'C$_{D}$/C$_{100}$')
plt.ylim(1e-2,1e4)
plt.xlim(1e-1,1e4)


plt.gcf().set_dpi(300)

plt.legend(fontsize=8)
plt.show()

# %%
import math
import numpy as np
x1=[100,500,1000,1500,2000,2500,3000,3500,4000,4500]
y1=[0.0375,0.058,0.042,0.035,0.02,0.015,0.01,0.005,0.004,0.005]

x2=[20,65,200,650,2000]
y2=[2.6,0.528571429,0.05,0.002857143,0.0005]


x3=[7.5,12.5,17.7,22.5,27.5,32.5,37.5,42.5,47.5,55,65,75,85,95,150,600]
y3=[9,4,1.5,1.2,1.4,0.6,0.6,0.6,0.6,0.3,0.3,0.3,0.3,0.05,0.008571429,0.01]


x4=[60,300,750,1500,3000]
y4=[0.255844156,0.11625,0.044,0.008,0.000766667]

x5=[11,18,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,462.5]
y5=[5.636363636,1.928571429,0.2,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.04]

x6=[300,750,3000]
y6=[0.055,0.058,0.01225]

x7=[0,12.5,37.5,62.5,87.5,112.5,137.5,161.5,187.5,215.5,237.5,287.5,3000]
y7=[2.2,1.28,0.4,0.2,0.1,0.04,0.04,0.04,0.04,0.04,0.04,0.04,0.00025]

x8=[17.5,65,200,650,3000]
y8=[2.4,0.428571429,0.05,0.007142857,0.0005]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

#plt.scatter(Size, Beijing, label=r'Beijing')
plt.scatter(x1, y1, label=r'Dongguan')
plt.scatter(x2, y2, label=r'Northern and Southeast China')
plt.scatter(x3, y3, label='Beijing')
plt.scatter(x4, y4, label='Shanghai')
plt.scatter(x5, y5, label='Alps to Arctic')
plt.scatter(x6, y6, label='Paris')
plt.scatter(x7, y7, label='Pristine mountain')
plt.scatter(x8, y8, label='Wenzhou')


y = 38.045*np.power([1,4000], -1.196)

# Plot the function


plt.plot([1,4000], y, label=r'Fitted Power Function: $y = 38.045 \times D^{-1.196}$' + f'\n$R^2$ = {0.8017}', color='blue')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Diameter (μm)')
plt.ylabel(r'd(Probability)/d(Diameter) (μm$^{-1}$)')
plt.title('Prbability density')
plt.xlim(1,1e4)



plt.gcf().set_dpi(300)

plt.legend(fontsize=7)
plt.show()
